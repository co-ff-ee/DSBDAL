# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = "Data Science is amazing. It helps in analyzing data and making decisions."
print(text)
# Out:
# Data Science is amazing. It helps in analyzing data and making decisions.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Data', 'Science', 'is', 'amazing', '.', 'It', 'helps', 'in', 'analyzing', 'data', 'and', 'making', 'decisions', '.']

# %%
stop_words = set(stopwords.words('english'))
filtered = [word for word in tokens if word.lower() not in stop_words]
print(filtered)
# Out:
# ['Data', 'Science', 'amazing', '.', 'helps', 'analyzing', 'data', 'making', 'decisions', '.']

# %%
ps = PorterStemmer()
stemmed = [ps.stem(word) for word in filtered]
print(stemmed)
# Out:
# ['data', 'scienc', 'amaz', '.', 'help', 'analyz', 'data', 'make', 'decis', '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered]
print(lemmatized)
# Out:
# ['Data', 'Science', 'amazing', '.', 'help', 'analyzing', 'data', 'making', 'decision', '.']

# %%
docs = [text]

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(docs)

print(vectorizer.get_feature_names_out())
print(tfidf.toarray())
# Out:
# ['amazing' 'analyzing' 'and' 'data' 'decisions' 'helps' 'in' 'is' 'it'
#  'making' 'science']
# [[0.26726124 0.26726124 0.26726124 0.53452248 0.26726124 0.26726124
#   0.26726124 0.26726124 0.26726124 0.26726124 0.26726124]]
